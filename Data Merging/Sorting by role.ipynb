# %%
import pandas as pd
import numpy as np

# %%
data = 'DataKeys/merged_data_2012_2018.csv'
full_df = pd.read_csv(data)
# Out:
# 2598

# %%
# Group By Roles
quarterback = full_df.loc[full_df["Position"] == "QB"]
output_data_QB = "GroupbyRoles/QB.csv"
quarterback.to_csv (output_data_QB, index = None, header=True)

widereceiver = full_df.loc[full_df["Position"] == "WR"]
output_data_WR = "GroupbyRoles/WR.csv"
widereceiver.to_csv (output_data_WR, index = None, header=True)

tightend = full_df.loc[full_df["Position"] == "TE"]
output_data_TE = "GroupbyRoles/TE.csv"
tightend.to_csv (output_data_TE, index = None, header=True)

runningback = full_df.loc[full_df["Position"] == "RB"]
output_data_RB = "GroupbyRoles/RB.csv"
runningback.to_csv (output_data_RB, index = None, header=True)

fullback = full_df.loc[full_df["Position"] == "FB"]
output_data_FB = "GroupbyRoles/FB.csv"
fullback.to_csv (output_data_FB, index = None, header=True)

kicker = full_df.loc[full_df["Position"] == "K"]
output_data_K = "GroupbyRoles/K.csv"
kicker.to_csv (output_data_K, index = None, header=True)


# Check that all positions have been accounted for
total = quarterback["Position"].count() + widereceiver["Position"].count() + tightend["Position"].count()+ runningback["Position"].count() + fullback["Position"].count() + kicker["Position"].count()

# %%
# Out:
#                Passing Average Yards  Passing Blitz  \
# Player Name
# AJ McCarron                 4.852333      13.666667
# Aaron Rodgers               7.624143     133.428571
# Alex Smith                  7.250857     128.714286
# Alex Tanney                 7.071000      12.000000
# Andrew Luck                 7.133000     178.166667
#
#                Average Passing Completion Percent  Passing Completions  \
# Player Name
# AJ McCarron                             49.906667            29.000000
# Aaron Rodgers                           64.679857           311.285714
# Alex Smith                              65.505000           277.857143
# Alex Tanney                             71.429000            10.000000
# Andrew Luck                             60.333167           333.333333
#
#                Passing Defended Passes  Passing Dropped Passes  \
# Player Name
# AJ McCarron                   3.333333                2.333333
# Aaron Rodgers                24.142857               27.428571
# Alex Smith                   21.285714               25.285714
# Alex Tanney                   2.000000                1.000000
# Andrew Luck                  33.333333               34.000000
#
#                Passing Gross Yards  Passing Hurries  Passing Interceptions  \
# Player Name
# AJ McCarron             309.333333        13.333333               0.666667
# Aaron Rodgers          3654.000000        52.428571               6.000000
# Alex Smith             3075.000000        37.285714               6.142857
# Alex Tanney              99.000000         5.000000               0.000000
# Andrew Luck            3945.166667        36.166667              13.833333
#
#                Passing Knockdowns  ...  Passing Net Yds  Passing Pocket Time  \
# Player Name                        ...
# AJ McCarron              4.333333  ...       283.000000           115.817667
# Aaron Rodgers           21.571429  ...      3416.142857           764.380571
# Alex Smith              17.000000  ...      2449.000000           614.451429
# Alex Tanney              0.000000  ...        65.000000            32.808000
# Andrew Luck             28.333333  ...      3069.833333           627.846000
#
#                Passing Rating  Passing Redzone Attempts  Passing Sack Yds  \
# Player Name
# AJ McCarron         67.633333                  3.333333         26.333333
# Aaron Rodgers      102.400000                 48.571429        237.857143
# Alex Smith          94.800000                 37.000000        182.714286
# Alex Tanney        114.900000                  2.000000         34.000000
# Andrew Luck         88.333333                 43.166667        187.333333
#
#                Passing Sacks  Passing Spikes  Passing Throw Away  \
# Player Name
# AJ McCarron         4.666667        0.000000            4.333333
# Aaron Rodgers      36.000000        0.857143           23.428571
# Alex Smith         34.000000        0.571429           16.000000
# Alex Tanney         3.000000        0.000000            0.000000
# Andrew Luck        29.000000        1.166667           11.166667
#
#                Passing Touchdowns  Passing Yards
# Player Name
# AJ McCarron              2.000000     309.333333
# Aaron Rodgers           29.428571    3654.000000
# Alex Smith              17.857143    3075.000000
# Alex Tanney              1.000000      99.000000
# Andrew Luck             28.500000    3945.166667
#
# [5 rows x 22 columns]
